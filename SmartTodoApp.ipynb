# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-bb41c4da-0f19-4800-95b8-08886ec45efc" name="files[]" multiple disabled />
#      <output id="result-bb41c4da-0f19-4800-95b8-08886ec45efc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2 year dataset.xlsx to 2 year dataset.xlsx
# ...

# %%
FILENAME = '2 year dataset.xlsx'

# %%
import pandas as pd

# %%
data = pd.read_excel(FILENAME)

# %%
data
# Out:
#             Date  apple  buger  chocolate  ...  mutton  spaghetti  wings   prac
# 0     1-Jan-2018      0      1          1  ...       1          1      1      1
# 1     2-Jan-2018      0      1          1  ...       0          0      0      1
# 2     3-Jan-2018      1      1          0  ...       1          1      1      1
# 3     4-Jan-2018      1      0          0  ...       1          0      0      1
# 4     5-Jan-2018      0      0          0  ...       0          1      1      1
# ..           ...    ...    ...        ...  ...     ...        ...    ...    ...
# 725  27-Dec-2019      1      1          1  ...       1          1      1      1
# 726  28-Dec-2019      0      0          1  ...       1          0      0      1
# 727  29-Dec-2019      1      1          1  ...       1          1      1      1
# 728  30-Dec-2019      0      1          0  ...       0          1      0      1
# 729  31-Dec-2019      1      0          1  ...       1          0      1      1
#
# ...
